# %%
pip install pandas numpy matplotlib seaborn plotly sqlalchemy requests scipy jupyter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df1= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/01_fund_master.csv")
print(df1.shape)
print(df1.dtypes)
print(df1.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df1.column
df1['scheme_name'].unique()
df1.describe()
df1.columns
# Out:
# (40, 15)
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
# <bound method NDFrame.head of     amfi_code                fund_house  \
# 0      119551           SBI Mutual Fund
# 1      119552           SBI Mutual Fund
# 2      119598           SBI Mutual Fund
# 3      119599           SBI Mutual Fund
# 4      119120           SBI Mutual Fund
# 5      100016          HDFC Mutual Fund
# 6      125497          HDFC Mutual Fund
# 7      100033          HDFC Mutual Fund
# 8      125498          HDFC Mutual Fund
# ...

# %%
df2= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/02_nav_history.csv")
print(df2.shape)
print(df2.dtypes)
print(df2.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df2['scheme_name'].unique()
df2.describe()

# %%
df3= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/03_aum_by_fund_house.csv")
print(df3.shape)
print(df3.dtypes)
print(df3.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df3['scheme_name'].unique()
df3.describe()

# %%
df4= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/04_monthly_sip_inflows (1).csv")
print(df4.shape)
print(df4.dtypes)
print(df4.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df4['scheme_name'].unique()
df4.describe()

# %%
df5= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/05_category_inflows.csv")
print(df5.shape)
print(df5.dtypes)
print(df5.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df5['scheme_name'].unique()
df5.describe()

# %%
df6= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/06_industry_folio_count.csv")
print(df6.shape)
print(df6.dtypes)
print(df6.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df6['scheme_name'].unique()
df6.describe()

# %%
df7= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/07_scheme_performance.csv")
print(df7.shape)
print(df7.dtypes)
print(df7.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df7['scheme_name'].unique()
df7.describe()

# %%
df8= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/08_investor_transactions.csv")
print(df8.shape)
print(df8.dtypes)
print(df8.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df8['scheme_name'].unique()
df8.describe()

# %%
df9= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/09_portfolio_holdings.csv")
print(df9.shape)
print(df9.dtypes)
print(df9.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df9['scheme_name'].unique()
df9.describe()

# %%
df10= pd.read_csv(r"C:\Users\manas\Mutual_Fund_Project/data/raw/10_benchmark_indices.csv")
print(df10.shape)
print(df10.dtypes)
print(df10.head)
print(df1.isnull().sum())
print(df1.duplicated().sum())
df10['scheme_name'].unique()
df10.describe()
